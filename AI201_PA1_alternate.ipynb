# %%
import os
import pandas as pd
file_path = './astar_in.txt'
data = pd.read_csv(file_path)

with open(file_path, 'r') as file:
    lines = [l.strip() for l in file.readlines() if len(l.split(' ')) == 3]
    start_list = ' '.join([l for l in lines[:3]]).split(' ')
    start_state = [l.split(' ') for l in lines[:3]]
    end_state = [l.split(' ') for l in lines[3:]]

# %%
def display_node(node):
    for i in range(len(node)):
        print(node[i])

# %% [markdown]
# ### Guide Pseudocode
#
# - Put the start node in the OPEN list
# - Check if the current node is already in the CLOSED list
#     - If yes, compare the score of the current node vs the node in the closed list
#         - If the node in the CLOSED list is lower, use that path
#         - If the node in the CLOSED list is higher, exit and choose the next node in the OPEN list
# - Check if the start/current node is the goal state
#     - If yes, return the solution
#     - Otherwise, add the node in the CLOSED list and continue with next step
# - Add the current node to the CLOSED list
# - Generate the list of expansion states from the start/current node
#     - Insert the list in the OPEN list
# - Compute the function by adding the ff:
#     - The path cost from the start node to each of the expanded states
#     - The manhattan distance of each expanded state to the goal state
# - The node with the lowest function score becomes the current node

# %%
display_node(start_state)

# %%
display_node(end_state)

# %%
import copy

def manhattan_calculator(start_state, end_state):
    manhattan_distance = 0
            
    for list1 in start_state:
        
        for item in list1:
            if item == '*':
                continue
            x1 = list1.index(item)
            y1 = start_state.index(list1)
            
            for list2 in end_state:
                
                if item in list2:
                    x2 = list2.index(item)
                    y2 = end_state.index(list2)
                    manhattan_distance += abs(x2-x1) + abs(y2-y1)
    
    return manhattan_distance

def no_of_wrong_tiles_calculator(node, end_state):
    
    no_of_wrong_tiles = 0
    
    l = 0
    for list in node:
        i = 0
        for item in list:
            if node[l][i] != '*' and node[l][i] != end_state[l][i]:
                no_of_wrong_tiles += 1
            i += 1
        l += 1
    
    return no_of_wrong_tiles

def get_clockwise_expectation(goal_state):
    end_state_1d = []
    clockwise_order = [0, 1, 2, 7, 8, 3, 6, 5, 4]
    for list in end_state:
        for item in list:
            end_state_1d.append(item)
    end_state_1d_clockwise = []
    num = 0
    end_state_1d_clockwise = copy.deepcopy(end_state_1d)
    for i in clockwise_order:
        end_state_1d_clockwise[i] = end_state_1d[num]
        num += 1

    end_state_1d_clockwise1 = copy.deepcopy(end_state_1d_clockwise)
    end_state_1d_clockwise.remove('*')
    end_state_1d_clockwise1.remove('*')
    end_state_1d_clockwise1.append(end_state_1d_clockwise1[0])
    clockwise_expectation = {}
    num = 0
    for i in end_state_1d_clockwise:
        clockwise_expectation[i] = end_state_1d_clockwise1[num+1]
        num += 1
    return clockwise_expectation

def nilsson_sequence_calculator(node, end_state):
    
    clockwise_expectation = get_clockwise_expectation(end_state)
    manhattan_distance = manhattan_calculator(start_state, end_state)
    sequence_score = 0

    for i in range(len(node)):
        for j in range(len(node)):
            if node[i][j] == '*':
                continue
            elif i == 1 and j == 1:
                sequence_score += 1
            else:
                if i == 0 and j < 2 and node[i][j + 1] != clockwise_expectation[node[i][j]]:
                    sequence_score += 2
                elif j == 2 and i < 2 and node[i + 1][j] != clockwise_expectation[node[i][j]]:
                    sequence_score += 2
                elif j > 0 and i == 2 and node[i][j - 1] != clockwise_expectation[node[i][j]]:
                    sequence_score += 2
                elif i > 0 and j == 0 and node[i - 1][j] != clockwise_expectation[node[i][j]]:
                    sequence_score += 2
                    
    nilsson_sequence_score = manhattan_distance + 3 * sequence_score
    return sequence_score

def expand_node(node):
    
    expanded_node_list = []
    
    for list in node:
        if list.count('*'):
            x = list.index('*')
            y = node.index(list)
            break
        else:
            continue
            
    x_left = x - 1
    x_right = x + 1
    y_up = y - 1
    y_down = y + 1
            
    if x_left >= 0:
        
        new_list = copy.deepcopy(node)
        new_list[y][x] = new_list[y][x_left]
        new_list[y][x_left] = '*'
        expanded_node_list.append(new_list)
            
    if x_right <= 2:
        
        new_list = copy.deepcopy(node)
        new_list[y][x] = new_list[y][x_right]
        new_list[y][x_right] = '*'
        expanded_node_list.append(new_list)
        
    if y_up >= 0:
        
        new_list = copy.deepcopy(node)
        new_list[y][x] = new_list[y_up][x]
        new_list[y_up][x] = '*'
        expanded_node_list.append(new_list)
        
    if y_down <= 2:
        
        new_list = copy.deepcopy(node)
        new_list[y][x] = new_list[y_down][x]
        new_list[y_down][x] = '*'
        expanded_node_list.append(new_list)
            
    return expanded_node_list

def goal_checker(node, goal_state):
    if node == goal_state: return True
    else: return False
    
def func_score(node, current_path_cost, goal_state, function_name):
    if function_name == 'manhattan distance':
        return current_path_cost + manhattan_calculator(node, goal_state), manhattan_calculator(node, goal_state)
    if function_name == 'nilsson sequence':
        return current_path_cost + manhattan_calculator(node, goal_state) + 3 * nilsson_sequence_calculator(node, goal_state), nilsson_sequence_calculator(node, goal_state), manhattan_calculator(node, goal_state) + 3 * nilsson_sequence_calculator(node, goal_state)
    if function_name == 'wrong tiles':
        return no_of_wrong_tiles_calculator(node, goal_state), no_of_wrong_tiles_calculator(node, goal_state)

# %%
def main_function(start_state, goal_state, function_name):
    
    current_node = copy.deepcopy(start_state)
    prev_node = copy.deepcopy(start_state)
    OPEN = []
    OPEN_scores = []
    step_costs = []
    current_solution = []
    correct_solution = []
    CLOSED = []
    CLOSED_info = []
    current_path_cost = 0
    OPEN.append(current_node)
    OPEN_scores.append(func_score(current_node, 0, goal_state, function_name)[0])
    step_costs.append(0)
    i = 0
    
    while len(OPEN) > 0:
        i += 1
        CLOSED_dict = {}

        display_node(current_node)
        index_of_current_node = OPEN.index(current_node)
        step_cost_of_current_node = step_costs[index_of_current_node]

        # print("Length of Open:", len(OPEN))
        # print("Length of OPEN_scores:", len(OPEN_scores))
        # print("Length of step_costs:", len(step_costs))
        # print('Open Scores:', OPEN_scores)
        print('g(n) =', step_costs[index_of_current_node], '(Current Step Cost)')
        
        if function_name == 'nilsson sequence':
            print('p(n) =', func_score(current_node, step_cost_of_current_node, goal_state, function_name)[1], '(Manhattan Distance)')
            print('s(n) =', func_score(current_node, step_cost_of_current_node, goal_state, function_name)[1], '(Sequence Score)')
            print('h(n) =', func_score(current_node, step_cost_of_current_node, goal_state, function_name)[2], '(Nilsson Sequence)')
        
        if function_name == 'manhattan distance':
            print('p(n) =', func_score(current_node, step_cost_of_current_node, goal_state, function_name)[1], '(Manhattan Distance)')
            
        if function_name == 'wrong tiles':
            print('m(n) =', func_score(current_node, step_cost_of_current_node, goal_state, function_name)[1], '(Wrong Tiles Count)')
        
        print('f(n) =', OPEN_scores[index_of_current_node], '(Function Score)')
            
        print('search cost:', len(CLOSED))
        print('------------------------------')
        if goal_checker(current_node, goal_state):
            correct_solution = current_solution
            return correct_solution, step_cost_of_current_node
        else:
            CLOSED.append(current_node)
            CLOSED_dict['score'] = func_score(current_node, step_cost_of_current_node, goal_state, function_name)[0]
            CLOSED_dict['sequence'] = copy.deepcopy(current_solution)
            CLOSED_info.append(CLOSED_dict)

        # Removing current node
        OPEN.pop(index_of_current_node)
        OPEN_scores.pop(index_of_current_node)
        step_costs.pop(index_of_current_node)
        current_solution.append(current_node)

        # Expand and add expansions to OPEN only if they
        # have not been met before in CLOSED and they don't
        # improve the previous score.
        expanded_states = expand_node(current_node)
        for expanded_state in expanded_states:
            x = func_score(expanded_state, step_cost_of_current_node + 1, goal_state, function_name)[0]
            if expanded_state in CLOSED or expanded_state in OPEN:
                if expanded_state in CLOSED:
                    y = CLOSED_info[CLOSED.index(expanded_state)].get('score')
                    if y < x:
                        current_solution = CLOSED_info[CLOSED.index(current_node)].get('sequence')
                    else:
                        OPEN.append(expanded_state)
                        OPEN_scores.append(x)
                        step_costs.append(step_cost_of_current_node + 1)
                elif expanded_state in OPEN:
                    y = OPEN_scores[OPEN.index(expanded_state)]
                    if y < x:
                        current_solution = CLOSED_info[CLOSED.index(current_node)].get('sequence')
                    else:
                        OPEN.append(expanded_state)
                        OPEN_scores.append(x)
                        step_costs.append(step_cost_of_current_node + 1)
            else:
                OPEN.append(expanded_state)
                OPEN_scores.append(x)
                step_costs.append(step_cost_of_current_node + 1)

        # Assigning new current node from remaining lowest scoring node in OPEN
        lowest_score_node_index = OPEN_scores.index(min(OPEN_scores))
        current_node = OPEN[lowest_score_node_index]

manhattan_result = main_function(start_state, end_state, 'manhattan distance')
# Out:
# ['2', '1', '6']
# ['4', '*', '8']
# ['7', '5', '3']
# g(n) = 0 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 12 (Function Score)
# search cost: 0
# ------------------------------
# ['2', '1', '6']
# ['*', '4', '8']
# ['7', '5', '3']
# g(n) = 1 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 12 (Function Score)
# search cost: 1
# ------------------------------
# ['2', '1', '6']
# ['4', '8', '*']
# ['7', '5', '3']
# g(n) = 1 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 12 (Function Score)
# search cost: 2
# ------------------------------
# ['2', '1', '*']
# ['4', '8', '6']
# ['7', '5', '3']
# g(n) = 2 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 12 (Function Score)
# search cost: 3
# ------------------------------
# ['2', '1', '6']
# ['4', '8', '3']
# ['7', '5', '*']
# g(n) = 2 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 12 (Function Score)
# search cost: 4
# ------------------------------
# ['2', '1', '6']
# ['4', '8', '3']
# ['7', '*', '5']
# g(n) = 3 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 12 (Function Score)
# search cost: 5
# ------------------------------
# ['2', '*', '6']
# ['4', '1', '8']
# ['7', '5', '3']
# g(n) = 1 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# f(n) = 14 (Function Score)
# search cost: 6
# ------------------------------
# ['2', '1', '6']
# ['4', '5', '8']
# ['7', '*', '3']
# g(n) = 1 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# f(n) = 14 (Function Score)
# search cost: 7
# ------------------------------
# ['*', '1', '6']
# ['2', '4', '8']
# ['7', '5', '3']
# g(n) = 2 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 14 (Function Score)
# search cost: 8
# ------------------------------
# ['2', '1', '6']
# ['7', '4', '8']
# ['*', '5', '3']
# g(n) = 2 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 14 (Function Score)
# search cost: 9
# ------------------------------
# ['2', '*', '1']
# ['4', '8', '6']
# ['7', '5', '3']
# g(n) = 3 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 14 (Function Score)
# search cost: 10
# ------------------------------
# ['2', '1', '6']
# ['4', '8', '3']
# ['*', '7', '5']
# g(n) = 4 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 14 (Function Score)
# search cost: 11
# ------------------------------
# ['2', '1', '6']
# ['4', '*', '3']
# ['7', '8', '5']
# g(n) = 4 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 14 (Function Score)
# search cost: 12
# ------------------------------
# ['*', '2', '6']
# ['4', '1', '8']
# ['7', '5', '3']
# g(n) = 2 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 14 (Function Score)
# search cost: 13
# ------------------------------
# ['2', '6', '*']
# ['4', '1', '8']
# ['7', '5', '3']
# g(n) = 2 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 14 (Function Score)
# search cost: 14
# ------------------------------
# ['1', '*', '6']
# ['2', '4', '8']
# ['7', '5', '3']
# g(n) = 3 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 14 (Function Score)
# search cost: 15
# ------------------------------
# ['*', '2', '1']
# ['4', '8', '6']
# ['7', '5', '3']
# g(n) = 4 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 14 (Function Score)
# search cost: 16
# ------------------------------
# ['2', '1', '6']
# ['*', '4', '3']
# ['7', '8', '5']
# g(n) = 5 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 14 (Function Score)
# search cost: 17
# ------------------------------
# ['1', '6', '*']
# ['2', '4', '8']
# ['7', '5', '3']
# g(n) = 4 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 14 (Function Score)
# search cost: 18
# ------------------------------
# ['2', '1', '6']
# ['4', '5', '8']
# ['*', '7', '3']
# g(n) = 2 (Current Step Cost)
# p(n) = 14 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 19
# ------------------------------
# ['2', '1', '6']
# ['4', '5', '8']
# ['7', '3', '*']
# g(n) = 2 (Current Step Cost)
# p(n) = 14 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 20
# ------------------------------
# ['2', '1', '6']
# ['7', '4', '8']
# ['5', '*', '3']
# g(n) = 3 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 21
# ------------------------------
# ['2', '8', '1']
# ['4', '*', '6']
# ['7', '5', '3']
# g(n) = 4 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 22
# ------------------------------
# ['2', '1', '6']
# ['*', '8', '3']
# ['4', '7', '5']
# g(n) = 5 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 23
# ------------------------------
# ['2', '1', '6']
# ['4', '3', '*']
# ['7', '8', '5']
# g(n) = 5 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 24
# ------------------------------
# ['2', '*', '6']
# ['4', '1', '3']
# ['7', '8', '5']
# g(n) = 5 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 25
# ------------------------------
# ['4', '2', '6']
# ['*', '1', '8']
# ['7', '5', '3']
# g(n) = 3 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 26
# ------------------------------
# ['2', '6', '8']
# ['4', '1', '*']
# ['7', '5', '3']
# g(n) = 3 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 27
# ------------------------------
# ['1', '4', '6']
# ['2', '*', '8']
# ['7', '5', '3']
# g(n) = 4 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 28
# ------------------------------
# ['4', '2', '1']
# ['*', '8', '6']
# ['7', '5', '3']
# g(n) = 5 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 29
# ------------------------------
# ['*', '1', '6']
# ['2', '4', '3']
# ['7', '8', '5']
# g(n) = 6 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 30
# ------------------------------
# ['2', '1', '6']
# ['7', '4', '3']
# ['*', '8', '5']
# g(n) = 6 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 31
# ------------------------------
# ['1', '6', '8']
# ['2', '4', '*']
# ['7', '5', '3']
# g(n) = 5 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 32
# ------------------------------
# ['2', '8', '1']
# ['*', '4', '6']
# ['7', '5', '3']
# g(n) = 5 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 33
# ------------------------------
# ['2', '8', '1']
# ['4', '6', '*']
# ['7', '5', '3']
# g(n) = 5 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 34
# ------------------------------
# ['2', '1', '6']
# ['8', '*', '3']
# ['4', '7', '5']
# g(n) = 6 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 35
# ------------------------------
# ['2', '1', '*']
# ['4', '3', '6']
# ['7', '8', '5']
# g(n) = 6 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 36
# ------------------------------
# ['*', '2', '6']
# ['4', '1', '3']
# ['7', '8', '5']
# g(n) = 6 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 37
# ------------------------------
# ['2', '6', '*']
# ['4', '1', '3']
# ['7', '8', '5']
# g(n) = 6 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 38
# ------------------------------
# ['4', '2', '6']
# ['1', '*', '8']
# ['7', '5', '3']
# g(n) = 4 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 39
# ------------------------------
# ['2', '6', '8']
# ['4', '1', '3']
# ['7', '5', '*']
# g(n) = 4 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 40
# ------------------------------
# ['1', '4', '6']
# ['*', '2', '8']
# ['7', '5', '3']
# g(n) = 5 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 41
# ------------------------------
# ['1', '4', '6']
# ['2', '8', '*']
# ['7', '5', '3']
# g(n) = 5 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 42
# ------------------------------
# ['4', '2', '1']
# ['8', '*', '6']
# ['7', '5', '3']
# g(n) = 6 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 43
# ------------------------------
# ['1', '*', '6']
# ['2', '4', '3']
# ['7', '8', '5']
# g(n) = 7 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 44
# ------------------------------
# ['2', '1', '6']
# ['7', '4', '3']
# ['8', '*', '5']
# g(n) = 7 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 45
# ------------------------------
# ['1', '6', '8']
# ['2', '*', '4']
# ['7', '5', '3']
# g(n) = 6 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 46
# ------------------------------
# ['1', '6', '8']
# ['2', '4', '3']
# ['7', '5', '*']
# g(n) = 6 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 47
# ------------------------------
# ['2', '8', '1']
# ['4', '6', '3']
# ['7', '5', '*']
# g(n) = 6 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 48
# ------------------------------
# ['2', '6', '3']
# ['4', '1', '*']
# ['7', '8', '5']
# g(n) = 7 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 49
# ------------------------------
# ['4', '2', '6']
# ['1', '8', '*']
# ['7', '5', '3']
# g(n) = 5 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 50
# ------------------------------
# ['2', '6', '8']
# ['4', '1', '3']
# ['7', '*', '5']
# g(n) = 5 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 51
# ------------------------------
# ['1', '4', '*']
# ['2', '8', '6']
# ['7', '5', '3']
# g(n) = 6 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 52
# ------------------------------
# ['1', '4', '6']
# ['2', '8', '3']
# ['7', '5', '*']
# g(n) = 6 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 53
# ------------------------------
# ['4', '2', '1']
# ['8', '6', '*']
# ['7', '5', '3']
# g(n) = 7 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 54
# ------------------------------
# ['1', '6', '*']
# ['2', '4', '3']
# ['7', '8', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 55
# ------------------------------
# ['1', '6', '8']
# ['*', '2', '4']
# ['7', '5', '3']
# g(n) = 7 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 56
# ------------------------------
# ['1', '*', '8']
# ['2', '6', '4']
# ['7', '5', '3']
# g(n) = 7 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 57
# ------------------------------
# ['1', '6', '8']
# ['2', '4', '3']
# ['7', '*', '5']
# g(n) = 7 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 58
# ------------------------------
# ['2', '8', '1']
# ['4', '6', '3']
# ['7', '*', '5']
# g(n) = 7 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 59
# ------------------------------
# ['4', '2', '*']
# ['1', '8', '6']
# ['7', '5', '3']
# g(n) = 6 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 60
# ------------------------------
# ['4', '2', '6']
# ['1', '8', '3']
# ['7', '5', '*']
# g(n) = 6 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 61
# ------------------------------
# ['1', '*', '4']
# ['2', '8', '6']
# ['7', '5', '3']
# g(n) = 7 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 62
# ------------------------------
# ['1', '4', '6']
# ['2', '8', '3']
# ['7', '*', '5']
# g(n) = 7 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 63
# ------------------------------
# ['4', '2', '1']
# ['8', '6', '3']
# ['7', '5', '*']
# g(n) = 8 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 64
# ------------------------------
# ['1', '6', '3']
# ['2', '4', '*']
# ['7', '8', '5']
# g(n) = 9 (Current Step Cost)
# p(n) = 7 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 65
# ------------------------------
# ['1', '8', '*']
# ['2', '6', '4']
# ['7', '5', '3']
# g(n) = 8 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 66
# ------------------------------
# ['2', '8', '1']
# ['4', '*', '3']
# ['7', '6', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 67
# ------------------------------
# ['4', '2', '6']
# ['1', '8', '3']
# ['7', '*', '5']
# g(n) = 7 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 68
# ------------------------------
# ['4', '2', '1']
# ['8', '6', '3']
# ['7', '*', '5']
# g(n) = 9 (Current Step Cost)
# p(n) = 7 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 69
# ------------------------------
# ['1', '6', '3']
# ['2', '*', '4']
# ['7', '8', '5']
# g(n) = 10 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 70
# ------------------------------
# ['2', '8', '1']
# ['*', '4', '3']
# ['7', '6', '5']
# g(n) = 9 (Current Step Cost)
# p(n) = 7 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 71
# ------------------------------
# ['2', '*', '1']
# ['4', '8', '3']
# ['7', '6', '5']
# g(n) = 9 (Current Step Cost)
# p(n) = 7 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 72
# ------------------------------
# ['4', '2', '1']
# ['8', '*', '3']
# ['7', '6', '5']
# g(n) = 10 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 73
# ------------------------------
# ['1', '6', '3']
# ['*', '2', '4']
# ['7', '8', '5']
# g(n) = 11 (Current Step Cost)
# p(n) = 5 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 74
# ------------------------------
# ['1', '*', '3']
# ['2', '6', '4']
# ['7', '8', '5']
# g(n) = 11 (Current Step Cost)
# p(n) = 5 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 75
# ------------------------------
# ['1', '6', '3']
# ['2', '8', '4']
# ['7', '*', '5']
# g(n) = 11 (Current Step Cost)
# p(n) = 5 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 76
# ------------------------------
# ['*', '2', '1']
# ['4', '8', '3']
# ['7', '6', '5']
# g(n) = 10 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 77
# ------------------------------
# ['2', '1', '*']
# ['4', '8', '3']
# ['7', '6', '5']
# g(n) = 10 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 78
# ------------------------------
# ['2', '1', '3']
# ['4', '8', '*']
# ['7', '6', '5']
# g(n) = 11 (Current Step Cost)
# p(n) = 5 (Manhattan Distance)
# f(n) = 16 (Function Score)
# search cost: 79
# ------------------------------
# ['2', '1', '6']
# ['*', '5', '8']
# ['4', '7', '3']
# g(n) = 3 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 80
# ------------------------------
# ['2', '1', '6']
# ['4', '5', '*']
# ['7', '3', '8']
# g(n) = 3 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 81
# ------------------------------
# ['2', '1', '6']
# ['7', '4', '8']
# ['5', '3', '*']
# g(n) = 4 (Current Step Cost)
# p(n) = 14 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 82
# ------------------------------
# ['2', '1', '6']
# ['7', '*', '8']
# ['5', '4', '3']
# g(n) = 4 (Current Step Cost)
# p(n) = 14 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 83
# ------------------------------
# ['2', '8', '1']
# ['4', '5', '6']
# ['7', '*', '3']
# g(n) = 5 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 84
# ------------------------------
# ['*', '1', '6']
# ['2', '8', '3']
# ['4', '7', '5']
# g(n) = 6 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 85
# ------------------------------
# ['2', '1', '6']
# ['4', '3', '5']
# ['7', '8', '*']
# g(n) = 6 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 86
# ------------------------------
# ['4', '2', '6']
# ['7', '1', '8']
# ['*', '5', '3']
# g(n) = 4 (Current Step Cost)
# p(n) = 14 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 87
# ------------------------------
# ['2', '6', '8']
# ['4', '*', '1']
# ['7', '5', '3']
# g(n) = 4 (Current Step Cost)
# p(n) = 14 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 88
# ------------------------------
# ['1', '4', '6']
# ['2', '5', '8']
# ['7', '*', '3']
# g(n) = 5 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 89
# ------------------------------
# ['4', '2', '1']
# ['7', '8', '6']
# ['*', '5', '3']
# g(n) = 6 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 90
# ------------------------------
# ['*', '8', '1']
# ['2', '4', '6']
# ['7', '5', '3']
# g(n) = 6 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 91
# ------------------------------
# ['2', '8', '1']
# ['7', '4', '6']
# ['*', '5', '3']
# g(n) = 6 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 92
# ------------------------------
# ['2', '8', '*']
# ['4', '6', '1']
# ['7', '5', '3']
# g(n) = 6 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 93
# ------------------------------
# ['2', '1', '6']
# ['8', '3', '*']
# ['4', '7', '5']
# g(n) = 7 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 94
# ------------------------------
# ['2', '*', '6']
# ['8', '1', '3']
# ['4', '7', '5']
# g(n) = 7 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 95
# ------------------------------
# ['2', '1', '6']
# ['8', '7', '3']
# ['4', '*', '5']
# g(n) = 7 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 96
# ------------------------------
# ['2', '*', '1']
# ['4', '3', '6']
# ['7', '8', '5']
# g(n) = 7 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 97
# ------------------------------
# ['4', '2', '6']
# ['*', '1', '3']
# ['7', '8', '5']
# g(n) = 7 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 98
# ------------------------------
# ['4', '*', '6']
# ['1', '2', '8']
# ['7', '5', '3']
# g(n) = 5 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 99
# ------------------------------
# ['4', '2', '6']
# ['1', '5', '8']
# ['7', '*', '3']
# g(n) = 5 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 100
# ------------------------------
# ['*', '4', '6']
# ['1', '2', '8']
# ['7', '5', '3']
# g(n) = 6 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 101
# ------------------------------
# ['1', '4', '6']
# ['7', '2', '8']
# ['*', '5', '3']
# g(n) = 6 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 102
# ------------------------------
# ['4', '*', '1']
# ['8', '2', '6']
# ['7', '5', '3']
# g(n) = 7 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 103
# ------------------------------
# ['4', '2', '1']
# ['8', '5', '6']
# ['7', '*', '3']
# g(n) = 7 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 104
# ------------------------------
# ['1', '4', '6']
# ['2', '*', '3']
# ['7', '8', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 105
# ------------------------------
# ['2', '1', '6']
# ['7', '4', '3']
# ['8', '5', '*']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 106
# ------------------------------
# ['2', '1', '6']
# ['7', '*', '3']
# ['8', '4', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 107
# ------------------------------
# ['1', '6', '8']
# ['2', '5', '4']
# ['7', '*', '3']
# g(n) = 7 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 108
# ------------------------------
# ['2', '6', '3']
# ['4', '*', '1']
# ['7', '8', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 109
# ------------------------------
# ['2', '6', '3']
# ['4', '1', '5']
# ['7', '8', '*']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 110
# ------------------------------
# ['2', '6', '8']
# ['4', '1', '3']
# ['*', '7', '5']
# g(n) = 6 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 111
# ------------------------------
# ['2', '6', '8']
# ['4', '*', '3']
# ['7', '1', '5']
# g(n) = 6 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 112
# ------------------------------
# ['4', '2', '*']
# ['8', '6', '1']
# ['7', '5', '3']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 113
# ------------------------------
# ['*', '6', '8']
# ['1', '2', '4']
# ['7', '5', '3']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 114
# ------------------------------
# ['1', '6', '8']
# ['7', '2', '4']
# ['*', '5', '3']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 115
# ------------------------------
# ['*', '1', '8']
# ['2', '6', '4']
# ['7', '5', '3']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 116
# ------------------------------
# ['1', '6', '8']
# ['2', '4', '3']
# ['*', '7', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 117
# ------------------------------
# ['1', '6', '8']
# ['2', '*', '3']
# ['7', '4', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 118
# ------------------------------
# ['2', '8', '1']
# ['4', '6', '3']
# ['*', '7', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 119
# ------------------------------
# ['4', '*', '2']
# ['1', '8', '6']
# ['7', '5', '3']
# g(n) = 7 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 120
# ------------------------------
# ['*', '1', '4']
# ['2', '8', '6']
# ['7', '5', '3']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 121
# ------------------------------
# ['1', '8', '4']
# ['2', '*', '6']
# ['7', '5', '3']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 122
# ------------------------------
# ['1', '4', '6']
# ['2', '8', '3']
# ['*', '7', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 123
# ------------------------------
# ['1', '4', '6']
# ['2', '*', '3']
# ['7', '8', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 124
# ------------------------------
# ['1', '6', '3']
# ['2', '4', '5']
# ['7', '8', '*']
# g(n) = 10 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 125
# ------------------------------
# ['1', '8', '4']
# ['2', '6', '*']
# ['7', '5', '3']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 126
# ------------------------------
# ['2', '8', '1']
# ['4', '3', '*']
# ['7', '6', '5']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 127
# ------------------------------
# ['4', '2', '6']
# ['1', '8', '3']
# ['*', '7', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 128
# ------------------------------
# ['4', '2', '6']
# ['1', '*', '3']
# ['7', '8', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 129
# ------------------------------
# ['4', '2', '1']
# ['8', '6', '3']
# ['*', '7', '5']
# g(n) = 10 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 130
# ------------------------------
# ['*', '8', '1']
# ['2', '4', '3']
# ['7', '6', '5']
# g(n) = 10 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 131
# ------------------------------
# ['2', '8', '1']
# ['7', '4', '3']
# ['*', '6', '5']
# g(n) = 10 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 132
# ------------------------------
# ['4', '2', '1']
# ['*', '8', '3']
# ['7', '6', '5']
# g(n) = 11 (Current Step Cost)
# p(n) = 7 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 133
# ------------------------------
# ['4', '2', '1']
# ['8', '3', '*']
# ['7', '6', '5']
# g(n) = 11 (Current Step Cost)
# p(n) = 7 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 134
# ------------------------------
# ['4', '*', '1']
# ['8', '2', '3']
# ['7', '6', '5']
# g(n) = 11 (Current Step Cost)
# p(n) = 7 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 135
# ------------------------------
# ['*', '6', '3']
# ['1', '2', '4']
# ['7', '8', '5']
# g(n) = 12 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 136
# ------------------------------
# ['1', '6', '3']
# ['7', '2', '4']
# ['*', '8', '5']
# g(n) = 12 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 137
# ------------------------------
# ['*', '1', '3']
# ['2', '6', '4']
# ['7', '8', '5']
# g(n) = 12 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 138
# ------------------------------
# ['1', '3', '*']
# ['2', '6', '4']
# ['7', '8', '5']
# g(n) = 12 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 139
# ------------------------------
# ['1', '6', '3']
# ['2', '8', '4']
# ['*', '7', '5']
# g(n) = 12 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 140
# ------------------------------
# ['1', '6', '3']
# ['2', '8', '4']
# ['7', '5', '*']
# g(n) = 12 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 141
# ------------------------------
# ['4', '2', '1']
# ['*', '8', '3']
# ['7', '6', '5']
# g(n) = 11 (Current Step Cost)
# p(n) = 7 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 142
# ------------------------------
# ['2', '1', '3']
# ['4', '*', '8']
# ['7', '6', '5']
# g(n) = 12 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 143
# ------------------------------
# ['2', '1', '3']
# ['4', '8', '5']
# ['7', '6', '*']
# g(n) = 12 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 144
# ------------------------------
# ['2', '1', '6']
# ['4', '*', '5']
# ['7', '3', '8']
# g(n) = 4 (Current Step Cost)
# p(n) = 14 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 145
# ------------------------------
# ['2', '1', '*']
# ['4', '5', '6']
# ['7', '3', '8']
# g(n) = 4 (Current Step Cost)
# p(n) = 14 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 146
# ------------------------------
# ['2', '1', '6']
# ['7', '8', '*']
# ['5', '4', '3']
# g(n) = 5 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 147
# ------------------------------
# ['1', '*', '6']
# ['2', '8', '3']
# ['4', '7', '5']
# g(n) = 7 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 148
# ------------------------------
# ['2', '6', '8']
# ['*', '4', '1']
# ['7', '5', '3']
# g(n) = 5 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 149
# ------------------------------
# ['2', '*', '8']
# ['4', '6', '1']
# ['7', '5', '3']
# g(n) = 5 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 150
# ------------------------------
# ['8', '*', '1']
# ['2', '4', '6']
# ['7', '5', '3']
# g(n) = 7 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 151
# ------------------------------
# ['2', '1', '*']
# ['8', '3', '6']
# ['4', '7', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 152
# ------------------------------
# ['*', '2', '6']
# ['8', '1', '3']
# ['4', '7', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 153
# ------------------------------
# ['2', '6', '*']
# ['8', '1', '3']
# ['4', '7', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 154
# ------------------------------
# ['2', '1', '6']
# ['8', '7', '3']
# ['*', '4', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 155
# ------------------------------
# ['*', '2', '1']
# ['4', '3', '6']
# ['7', '8', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 156
# ------------------------------
# ['2', '3', '1']
# ['4', '*', '6']
# ['7', '8', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 157
# ------------------------------
# ['4', '2', '6']
# ['1', '*', '3']
# ['7', '8', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 158
# ------------------------------
# ['*', '4', '6']
# ['1', '2', '8']
# ['7', '5', '3']
# g(n) = 6 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 159
# ------------------------------
# ['4', '6', '*']
# ['1', '2', '8']
# ['7', '5', '3']
# g(n) = 6 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 160
# ------------------------------
# ['*', '4', '1']
# ['8', '2', '6']
# ['7', '5', '3']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 161
# ------------------------------
# ['4', '1', '*']
# ['8', '2', '6']
# ['7', '5', '3']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 162
# ------------------------------
# ['1', '4', '6']
# ['*', '2', '3']
# ['7', '8', '5']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 163
# ------------------------------
# ['2', '6', '3']
# ['*', '4', '1']
# ['7', '8', '5']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 164
# ------------------------------
# ['2', '*', '3']
# ['4', '6', '1']
# ['7', '8', '5']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 165
# ------------------------------
# ['2', '6', '3']
# ['4', '8', '1']
# ['7', '*', '5']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 166
# ------------------------------
# ['2', '6', '8']
# ['*', '4', '3']
# ['7', '1', '5']
# g(n) = 7 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 167
# ------------------------------
# ['2', '*', '8']
# ['4', '6', '3']
# ['7', '1', '5']
# g(n) = 7 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 168
# ------------------------------
# ['2', '1', '8']
# ['*', '6', '4']
# ['7', '5', '3']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 169
# ------------------------------
# ['1', '6', '8']
# ['*', '2', '3']
# ['7', '4', '5']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 170
# ------------------------------
# ['1', '*', '8']
# ['2', '6', '3']
# ['7', '4', '5']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 171
# ------------------------------
# ['*', '4', '2']
# ['1', '8', '6']
# ['7', '5', '3']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 172
# ------------------------------
# ['2', '1', '4']
# ['*', '8', '6']
# ['7', '5', '3']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 173
# ------------------------------
# ['1', '8', '4']
# ['*', '2', '6']
# ['7', '5', '3']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 174
# ------------------------------
# ['1', '8', '4']
# ['2', '6', '*']
# ['7', '5', '3']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 175
# ------------------------------
# ['1', '4', '6']
# ['*', '2', '3']
# ['7', '8', '5']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 176
# ------------------------------
# ['1', '8', '4']
# ['2', '6', '3']
# ['7', '5', '*']
# g(n) = 10 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 177
# ------------------------------
# ['8', '*', '1']
# ['2', '4', '3']
# ['7', '6', '5']
# g(n) = 11 (Current Step Cost)
# p(n) = 7 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 178
# ------------------------------
# ['*', '4', '1']
# ['8', '2', '3']
# ['7', '6', '5']
# g(n) = 12 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 179
# ------------------------------
# ['4', '1', '*']
# ['8', '2', '3']
# ['7', '6', '5']
# g(n) = 12 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 180
# ------------------------------
# ['1', '6', '3']
# ['7', '2', '4']
# ['8', '*', '5']
# g(n) = 13 (Current Step Cost)
# p(n) = 5 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 181
# ------------------------------
# ['2', '1', '3']
# ['*', '6', '4']
# ['7', '8', '5']
# g(n) = 13 (Current Step Cost)
# p(n) = 5 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 182
# ------------------------------
# ['2', '1', '3']
# ['*', '4', '8']
# ['7', '6', '5']
# g(n) = 13 (Current Step Cost)
# p(n) = 5 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 183
# ------------------------------
# ['2', '1', '6']
# ['*', '4', '5']
# ['7', '3', '8']
# g(n) = 5 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 184
# ------------------------------
# ['2', '1', '6']
# ['4', '3', '5']
# ['7', '*', '8']
# g(n) = 7 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# f(n) = 20 (Function Score)
# search cost: 185
# ------------------------------
# ['2', '1', '6']
# ['4', '3', '5']
# ['7', '*', '8']
# g(n) = 5 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 186
# ------------------------------
# ['2', '1', '*']
# ['7', '8', '6']
# ['5', '4', '3']
# g(n) = 6 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 187
# ------------------------------
# ['2', '1', '6']
# ['7', '8', '3']
# ['5', '4', '*']
# g(n) = 6 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 188
# ------------------------------
# ['1', '6', '*']
# ['2', '8', '3']
# ['4', '7', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 189
# ------------------------------
# ['*', '2', '8']
# ['4', '6', '1']
# ['7', '5', '3']
# g(n) = 6 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 190
# ------------------------------
# ['2', '8', '*']
# ['4', '6', '1']
# ['7', '5', '3']
# g(n) = 6 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 191
# ------------------------------
# ['8', '1', '*']
# ['2', '4', '6']
# ['7', '5', '3']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 192
# ------------------------------
# ['2', '6', '3']
# ['8', '1', '*']
# ['4', '7', '5']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 193
# ------------------------------
# ['2', '3', '1']
# ['*', '4', '6']
# ['7', '8', '5']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 194
# ------------------------------
# ['2', '3', '1']
# ['4', '6', '*']
# ['7', '8', '5']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 195
# ------------------------------
# ['2', '3', '1']
# ['4', '8', '6']
# ['7', '*', '5']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 196
# ------------------------------
# ['*', '2', '3']
# ['4', '6', '1']
# ['7', '8', '5']
# g(n) = 10 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 197
# ------------------------------
# ['*', '2', '8']
# ['4', '6', '3']
# ['7', '1', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 198
# ------------------------------
# ['2', '8', '*']
# ['4', '6', '3']
# ['7', '1', '5']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 199
# ------------------------------
# ['1', '8', '*']
# ['2', '6', '3']
# ['7', '4', '5']
# g(n) = 10 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 200
# ------------------------------
# ['1', '4', '2']
# ['*', '8', '6']
# ['7', '5', '3']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 201
# ------------------------------
# ['2', '1', '4']
# ['8', '*', '6']
# ['7', '5', '3']
# g(n) = 10 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 202
# ------------------------------
# ['1', '8', '4']
# ['2', '6', '3']
# ['7', '5', '*']
# g(n) = 10 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 203
# ------------------------------
# ['1', '8', '4']
# ['2', '6', '3']
# ['7', '*', '5']
# g(n) = 11 (Current Step Cost)
# p(n) = 7 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 204
# ------------------------------
# ['8', '1', '*']
# ['2', '4', '3']
# ['7', '6', '5']
# g(n) = 12 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 205
# ------------------------------
# ['4', '1', '3']
# ['8', '2', '*']
# ['7', '6', '5']
# g(n) = 13 (Current Step Cost)
# p(n) = 5 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 206
# ------------------------------
# ['2', '1', '6']
# ['4', '3', '5']
# ['7', '8', '*']
# g(n) = 6 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 207
# ------------------------------
# ['2', '1', '6']
# ['7', '8', '3']
# ['5', '*', '4']
# g(n) = 7 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 208
# ------------------------------
# ['1', '6', '3']
# ['2', '8', '*']
# ['4', '7', '5']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 209
# ------------------------------
# ['2', '8', '3']
# ['4', '6', '*']
# ['7', '1', '5']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 210
# ------------------------------
# ['1', '8', '3']
# ['2', '6', '*']
# ['7', '4', '5']
# g(n) = 11 (Current Step Cost)
# p(n) = 7 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 211
# ------------------------------
# ['1', '4', '2']
# ['8', '*', '6']
# ['7', '5', '3']
# g(n) = 10 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 212
# ------------------------------
# ['2', '1', '4']
# ['8', '6', '*']
# ['7', '5', '3']
# g(n) = 11 (Current Step Cost)
# p(n) = 7 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 213
# ------------------------------
# ['1', '8', '4']
# ['2', '6', '3']
# ['7', '*', '5']
# g(n) = 11 (Current Step Cost)
# p(n) = 7 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 214
# ------------------------------
# ['1', '8', '4']
# ['2', '*', '3']
# ['7', '6', '5']
# g(n) = 12 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 215
# ------------------------------
# ['8', '1', '3']
# ['2', '4', '*']
# ['7', '6', '5']
# g(n) = 13 (Current Step Cost)
# p(n) = 5 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 216
# ------------------------------
# ['2', '1', '6']
# ['7', '8', '3']
# ['*', '5', '4']
# g(n) = 8 (Current Step Cost)
# p(n) = 10 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 217
# ------------------------------
# ['1', '4', '2']
# ['8', '6', '*']
# ['7', '5', '3']
# g(n) = 11 (Current Step Cost)
# p(n) = 7 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 218
# ------------------------------
# ['1', '*', '2']
# ['8', '4', '6']
# ['7', '5', '3']
# g(n) = 11 (Current Step Cost)
# p(n) = 7 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 219
# ------------------------------
# ['2', '1', '*']
# ['8', '6', '4']
# ['7', '5', '3']
# g(n) = 12 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 220
# ------------------------------
# ['2', '1', '4']
# ['8', '6', '3']
# ['7', '5', '*']
# g(n) = 12 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 221
# ------------------------------
# ['1', '8', '4']
# ['2', '*', '3']
# ['7', '6', '5']
# g(n) = 12 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 222
# ------------------------------
# ['1', '8', '4']
# ['*', '2', '3']
# ['7', '6', '5']
# g(n) = 13 (Current Step Cost)
# p(n) = 5 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 223
# ------------------------------
# ['1', '*', '4']
# ['2', '8', '3']
# ['7', '6', '5']
# g(n) = 13 (Current Step Cost)
# p(n) = 5 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 224
# ------------------------------
# ['8', '1', '3']
# ['2', '*', '4']
# ['7', '6', '5']
# g(n) = 14 (Current Step Cost)
# p(n) = 4 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 225
# ------------------------------
# ['2', '1', '6']
# ['*', '8', '3']
# ['7', '5', '4']
# g(n) = 9 (Current Step Cost)
# p(n) = 9 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 226
# ------------------------------
# ['1', '4', '2']
# ['8', '6', '3']
# ['7', '5', '*']
# g(n) = 12 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 227
# ------------------------------
# ['1', '2', '*']
# ['8', '4', '6']
# ['7', '5', '3']
# g(n) = 12 (Current Step Cost)
# p(n) = 6 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 228
# ------------------------------
# ['2', '1', '4']
# ['8', '6', '3']
# ['7', '*', '5']
# g(n) = 13 (Current Step Cost)
# p(n) = 5 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 229
# ------------------------------
# ['1', '8', '4']
# ['*', '2', '3']
# ['7', '6', '5']
# g(n) = 13 (Current Step Cost)
# p(n) = 5 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 230
# ------------------------------
# ['1', '*', '4']
# ['2', '8', '3']
# ['7', '6', '5']
# g(n) = 13 (Current Step Cost)
# p(n) = 5 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 231
# ------------------------------
# ['8', '1', '3']
# ['*', '2', '4']
# ['7', '6', '5']
# g(n) = 15 (Current Step Cost)
# p(n) = 3 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 232
# ------------------------------
# ['2', '1', '6']
# ['8', '*', '3']
# ['7', '5', '4']
# g(n) = 10 (Current Step Cost)
# p(n) = 8 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 233
# ------------------------------
# ['1', '4', '2']
# ['8', '6', '3']
# ['7', '*', '5']
# g(n) = 13 (Current Step Cost)
# p(n) = 5 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 234
# ------------------------------
# ['2', '1', '4']
# ['8', '*', '3']
# ['7', '6', '5']
# g(n) = 14 (Current Step Cost)
# p(n) = 4 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 235
# ------------------------------
# ['*', '1', '3']
# ['8', '2', '4']
# ['7', '6', '5']
# g(n) = 16 (Current Step Cost)
# p(n) = 2 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 236
# ------------------------------
# ['1', '4', '2']
# ['8', '*', '3']
# ['7', '6', '5']
# g(n) = 14 (Current Step Cost)
# p(n) = 4 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 237
# ------------------------------
# ['1', '*', '3']
# ['8', '2', '4']
# ['7', '6', '5']
# g(n) = 17 (Current Step Cost)
# p(n) = 1 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 238
# ------------------------------
# ['1', '*', '2']
# ['8', '4', '3']
# ['7', '6', '5']
# g(n) = 15 (Current Step Cost)
# p(n) = 3 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 239
# ------------------------------
# ['1', '2', '3']
# ['8', '*', '4']
# ['7', '6', '5']
# g(n) = 18 (Current Step Cost)
# p(n) = 0 (Manhattan Distance)
# f(n) = 18 (Function Score)
# search cost: 240
# ------------------------------

# %%
main_function(start_state, end_state, 'nilsson sequence')
# Out:
# ['2', '1', '6']
# ['4', '*', '8']
# ['7', '5', '3']
# Length of Open: 1
# Length of OPEN_scores: 1
# Length of step_costs: 1
# Open Scores: [60]
# f(n) = 60 (Function Score)
# g(n) = 0 (Current Step Cost)
# p(n) = 16 (Manhattan Distance)
# s(n) = 16 (Sequence Score)
# h(n) = 60 (Nilsson Sequence)
# search cost: 0
# ------------------------------
# ['2', '1', '6']
# ['4', '*', '8']
# ['7', '5', '3']
# Length of Open: 4
# Length of OPEN_scores: 4
# Length of step_costs: 5
# Open Scores: [58, 58, 60, 60]
# f(n) = 58 (Function Score)
# g(n) = 1 (Current Step Cost)
# p(n) = 16 (Manhattan Distance)
# s(n) = 16 (Sequence Score)
# h(n) = 60 (Nilsson Sequence)
# search cost: 2
# ------------------------------
# ['2', '1', '6']
# ['*', '4', '8']
# ['7', '5', '3']
# Length of Open: 5
# Length of OPEN_scores: 5
# Length of step_costs: 7
# Open Scores: [58, 60, 60, 61, 61]
# f(n) = 58 (Function Score)
# g(n) = 2 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 4
# ------------------------------
# ['2', '1', '6']
# ['4', '8', '*']
# ['7', '5', '3']
# Length of Open: 6
# Length of OPEN_scores: 6
# Length of step_costs: 9
# Open Scores: [60, 60, 61, 61, 60, 60]
# f(n) = 60 (Function Score)
# g(n) = 3 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 6
# ------------------------------
# ['2', '*', '6']
# ['4', '1', '8']
# ['7', '5', '3']
# Length of Open: 7
# Length of OPEN_scores: 7
# Length of step_costs: 11
# Open Scores: [60, 61, 61, 60, 60, 63, 63]
# f(n) = 60 (Function Score)
# g(n) = 4 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 59 (Nilsson Sequence)
# search cost: 8
# ------------------------------
# ['2', '1', '6']
# ['4', '5', '8']
# ['7', '*', '3']
# Length of Open: 8
# Length of OPEN_scores: 8
# Length of step_costs: 13
# Open Scores: [61, 61, 60, 60, 63, 63, 66, 66]
# f(n) = 60 (Function Score)
# g(n) = 5 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 59 (Nilsson Sequence)
# search cost: 10
# ------------------------------
# ['2', '1', '*']
# ['4', '8', '6']
# ['7', '5', '3']
# Length of Open: 8
# Length of OPEN_scores: 8
# Length of step_costs: 14
# Open Scores: [61, 61, 60, 63, 63, 66, 66, 63]
# f(n) = 60 (Function Score)
# g(n) = 6 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 12
# ------------------------------
# ['2', '1', '6']
# ['4', '8', '3']
# ['7', '5', '*']
# Length of Open: 8
# Length of OPEN_scores: 8
# Length of step_costs: 15
# Open Scores: [61, 61, 63, 63, 66, 66, 63, 62]
# f(n) = 61 (Function Score)
# g(n) = 7 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 14
# ------------------------------
# ['*', '1', '6']
# ['2', '4', '8']
# ['7', '5', '3']
# Length of Open: 8
# Length of OPEN_scores: 8
# Length of step_costs: 16
# Open Scores: [61, 63, 63, 66, 66, 63, 62, 65]
# f(n) = 61 (Function Score)
# g(n) = 8 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 59 (Nilsson Sequence)
# search cost: 16
# ------------------------------
# ['2', '1', '6']
# ['7', '4', '8']
# ['*', '5', '3']
# Length of Open: 8
# Length of OPEN_scores: 8
# Length of step_costs: 17
# Open Scores: [63, 63, 66, 66, 63, 62, 65, 68]
# f(n) = 62 (Function Score)
# g(n) = 9 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 59 (Nilsson Sequence)
# search cost: 18
# ------------------------------
# ['2', '1', '6']
# ['4', '8', '3']
# ['7', '*', '5']
# Length of Open: 9
# Length of OPEN_scores: 9
# Length of step_costs: 19
# Open Scores: [63, 63, 66, 66, 63, 65, 68, 67, 68]
# f(n) = 63 (Function Score)
# g(n) = 10 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 55 (Nilsson Sequence)
# search cost: 20
# ------------------------------
# ['*', '2', '6']
# ['4', '1', '8']
# ['7', '5', '3']
# Length of Open: 9
# Length of OPEN_scores: 9
# Length of step_costs: 20
# Open Scores: [63, 66, 66, 63, 65, 68, 67, 68, 70]
# f(n) = 63 (Function Score)
# g(n) = 11 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 59 (Nilsson Sequence)
# search cost: 22
# ------------------------------
# ['2', '6', '*']
# ['4', '1', '8']
# ['7', '5', '3']
# Length of Open: 9
# Length of OPEN_scores: 9
# Length of step_costs: 21
# Open Scores: [66, 66, 63, 65, 68, 67, 68, 70, 71]
# f(n) = 63 (Function Score)
# g(n) = 12 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 59 (Nilsson Sequence)
# search cost: 24
# ------------------------------
# ['2', '*', '1']
# ['4', '8', '6']
# ['7', '5', '3']
# Length of Open: 10
# Length of OPEN_scores: 10
# Length of step_costs: 23
# Open Scores: [66, 66, 65, 68, 67, 68, 70, 71, 70, 67]
# f(n) = 65 (Function Score)
# g(n) = 13 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 26
# ------------------------------
# ['1', '*', '6']
# ['2', '4', '8']
# ['7', '5', '3']
# Length of Open: 11
# Length of OPEN_scores: 11
# Length of step_costs: 25
# Open Scores: [66, 66, 68, 67, 68, 70, 71, 70, 67, 71, 74]
# f(n) = 66 (Function Score)
# g(n) = 14 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 28
# ------------------------------
# ['2', '1', '6']
# ['4', '5', '8']
# ['*', '7', '3']
# Length of Open: 11
# Length of OPEN_scores: 11
# Length of step_costs: 26
# Open Scores: [66, 68, 67, 68, 70, 71, 70, 67, 71, 74, 76]
# f(n) = 66 (Function Score)
# g(n) = 15 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 61 (Nilsson Sequence)
# search cost: 30
# ------------------------------
# ['2', '1', '6']
# ['4', '5', '8']
# ['7', '3', '*']
# Length of Open: 11
# Length of OPEN_scores: 11
# Length of step_costs: 27
# Open Scores: [68, 67, 68, 70, 71, 70, 67, 71, 74, 76, 77]
# f(n) = 67 (Function Score)
# g(n) = 16 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 61 (Nilsson Sequence)
# search cost: 32
# ------------------------------
# ['2', '1', '6']
# ['4', '8', '3']
# ['*', '7', '5']
# Length of Open: 11
# Length of OPEN_scores: 11
# Length of step_costs: 28
# Open Scores: [68, 68, 70, 71, 70, 67, 71, 74, 76, 77, 74]
# f(n) = 67 (Function Score)
# g(n) = 17 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 34
# ------------------------------
# ['2', '8', '1']
# ['4', '*', '6']
# ['7', '5', '3']
# Length of Open: 13
# Length of OPEN_scores: 13
# Length of step_costs: 31
# Open Scores: [68, 68, 70, 71, 70, 71, 74, 76, 77, 74, 69, 69, 71]
# f(n) = 68 (Function Score)
# g(n) = 18 (Current Step Cost)
# p(n) = 14 (Manhattan Distance)
# s(n) = 14 (Sequence Score)
# h(n) = 54 (Nilsson Sequence)
# search cost: 36
# ------------------------------
# ['2', '1', '6']
# ['7', '4', '8']
# ['5', '*', '3']
# Length of Open: 14
# Length of OPEN_scores: 14
# Length of step_costs: 33
# Open Scores: [68, 70, 71, 70, 71, 74, 76, 77, 74, 69, 69, 71, 80, 69]
# f(n) = 68 (Function Score)
# g(n) = 19 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 59 (Nilsson Sequence)
# search cost: 38
# ------------------------------
# ['2', '1', '6']
# ['4', '*', '3']
# ['7', '8', '5']
# Length of Open: 16
# Length of OPEN_scores: 16
# Length of step_costs: 36
# Open Scores: [70, 71, 70, 71, 74, 76, 77, 74, 69, 69, 71, 80, 69, 75, 77, 77]
# f(n) = 69 (Function Score)
# g(n) = 20 (Current Step Cost)
# p(n) = 16 (Manhattan Distance)
# s(n) = 16 (Sequence Score)
# h(n) = 58 (Nilsson Sequence)
# search cost: 40
# ------------------------------
# ['2', '8', '1']
# ['*', '4', '6']
# ['7', '5', '3']
# Length of Open: 17
# Length of OPEN_scores: 17
# Length of step_costs: 38
# Open Scores: [70, 71, 70, 71, 74, 76, 77, 74, 69, 71, 80, 69, 75, 77, 77, 74, 74]
# f(n) = 69 (Function Score)
# g(n) = 21 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# s(n) = 13 (Sequence Score)
# h(n) = 51 (Nilsson Sequence)
# search cost: 42
# ------------------------------
# ['2', '8', '1']
# ['4', '6', '*']
# ['7', '5', '3']
# Length of Open: 18
# Length of OPEN_scores: 18
# Length of step_costs: 40
# Open Scores: [70, 71, 70, 71, 74, 76, 77, 74, 71, 80, 69, 75, 77, 77, 74, 74, 81, 73]
# f(n) = 69 (Function Score)
# g(n) = 22 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# s(n) = 13 (Sequence Score)
# h(n) = 51 (Nilsson Sequence)
# search cost: 44
# ------------------------------
# ['2', '1', '6']
# ['7', '*', '8']
# ['5', '4', '3']
# Length of Open: 20
# Length of OPEN_scores: 20
# Length of step_costs: 43
# Open Scores: [70, 71, 70, 71, 74, 76, 77, 74, 71, 80, 75, 77, 77, 74, 74, 81, 73, 72, 70, 72]
# f(n) = 70 (Function Score)
# g(n) = 23 (Current Step Cost)
# p(n) = 12 (Manhattan Distance)
# s(n) = 12 (Sequence Score)
# h(n) = 50 (Nilsson Sequence)
# search cost: 46
# ------------------------------
# ['4', '2', '6']
# ['*', '1', '8']
# ['7', '5', '3']
# Length of Open: 21
# Length of OPEN_scores: 21
# Length of step_costs: 45
# Open Scores: [71, 70, 71, 74, 76, 77, 74, 71, 80, 75, 77, 77, 74, 74, 81, 73, 72, 70, 72, 84, 85]
# f(n) = 70 (Function Score)
# g(n) = 24 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 59 (Nilsson Sequence)
# search cost: 48
# ------------------------------
# ['*', '2', '1']
# ['4', '8', '6']
# ['7', '5', '3']
# Length of Open: 21
# Length of OPEN_scores: 21
# Length of step_costs: 46
# Open Scores: [71, 71, 74, 76, 77, 74, 71, 80, 75, 77, 77, 74, 74, 81, 73, 72, 70, 72, 84, 85, 82]
# f(n) = 70 (Function Score)
# g(n) = 25 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 50
# ------------------------------
# ['2', '1', '6']
# ['7', '8', '*']
# ['5', '4', '3']
# Length of Open: 22
# Length of OPEN_scores: 22
# Length of step_costs: 48
# Open Scores: [71, 71, 74, 76, 77, 74, 71, 80, 75, 77, 77, 74, 74, 81, 73, 72, 72, 84, 85, 82, 73, 79]
# f(n) = 71 (Function Score)
# g(n) = 26 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# s(n) = 11 (Sequence Score)
# h(n) = 47 (Nilsson Sequence)
# search cost: 52
# ------------------------------
# ['2', '6', '8']
# ['4', '1', '*']
# ['7', '5', '3']
# Length of Open: 23
# Length of OPEN_scores: 23
# Length of step_costs: 50
# Open Scores: [71, 74, 76, 77, 74, 71, 80, 75, 77, 77, 74, 74, 81, 73, 72, 72, 84, 85, 82, 73, 79, 83, 86]
# f(n) = 71 (Function Score)
# g(n) = 27 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 59 (Nilsson Sequence)
# search cost: 54
# ------------------------------
# ['1', '6', '*']
# ['2', '4', '8']
# ['7', '5', '3']
# Length of Open: 23
# Length of OPEN_scores: 23
# Length of step_costs: 51
# Open Scores: [74, 76, 77, 74, 71, 80, 75, 77, 77, 74, 74, 81, 73, 72, 72, 84, 85, 82, 73, 79, 83, 86, 85]
# f(n) = 71 (Function Score)
# g(n) = 28 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 56
# ------------------------------
# ['2', '8', '1']
# ['4', '5', '6']
# ['7', '*', '3']
# Length of Open: 24
# Length of OPEN_scores: 24
# Length of step_costs: 53
# Open Scores: [74, 76, 77, 74, 80, 75, 77, 77, 74, 74, 81, 73, 72, 72, 84, 85, 82, 73, 79, 83, 86, 85, 84, 84]
# f(n) = 72 (Function Score)
# g(n) = 29 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# s(n) = 13 (Sequence Score)
# h(n) = 53 (Nilsson Sequence)
# search cost: 58
# ------------------------------
# ['2', '1', '6']
# ['*', '7', '8']
# ['5', '4', '3']
# Length of Open: 25
# Length of OPEN_scores: 25
# Length of step_costs: 55
# Open Scores: [74, 76, 77, 74, 80, 75, 77, 77, 74, 74, 81, 73, 72, 84, 85, 82, 73, 79, 83, 86, 85, 84, 84, 81, 87]
# f(n) = 72 (Function Score)
# g(n) = 30 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# s(n) = 11 (Sequence Score)
# h(n) = 49 (Nilsson Sequence)
# search cost: 60
# ------------------------------
# ['2', '*', '6']
# ['7', '1', '8']
# ['5', '4', '3']
# Length of Open: 26
# Length of OPEN_scores: 26
# Length of step_costs: 57
# Open Scores: [74, 76, 77, 74, 80, 75, 77, 77, 74, 74, 81, 73, 84, 85, 82, 73, 79, 83, 86, 85, 84, 84, 81, 87, 80, 80]
# f(n) = 73 (Function Score)
# g(n) = 31 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# s(n) = 11 (Sequence Score)
# h(n) = 49 (Nilsson Sequence)
# search cost: 62
# ------------------------------
# ['2', '8', '1']
# ['4', '6', '3']
# ['7', '5', '*']
# Length of Open: 26
# Length of OPEN_scores: 26
# Length of step_costs: 58
# Open Scores: [74, 76, 77, 74, 80, 75, 77, 77, 74, 74, 81, 84, 85, 82, 73, 79, 83, 86, 85, 84, 84, 81, 87, 80, 80, 81]
# f(n) = 73 (Function Score)
# g(n) = 32 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# s(n) = 13 (Sequence Score)
# h(n) = 51 (Nilsson Sequence)
# search cost: 64
# ------------------------------
# ['2', '1', '*']
# ['7', '8', '6']
# ['5', '4', '3']
# Length of Open: 26
# Length of OPEN_scores: 26
# Length of step_costs: 59
# Open Scores: [74, 76, 77, 74, 80, 75, 77, 77, 74, 74, 81, 84, 85, 82, 79, 83, 86, 85, 84, 84, 81, 87, 80, 80, 81, 80]
# f(n) = 74 (Function Score)
# g(n) = 33 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# s(n) = 11 (Sequence Score)
# h(n) = 47 (Nilsson Sequence)
# search cost: 66
# ------------------------------
# ['1', '4', '6']
# ['2', '*', '8']
# ['7', '5', '3']
# Length of Open: 28
# Length of OPEN_scores: 28
# Length of step_costs: 62
# Open Scores: [76, 77, 74, 80, 75, 77, 77, 74, 74, 81, 84, 85, 82, 79, 83, 86, 85, 84, 84, 81, 87, 80, 80, 81, 80, 91, 91, 93]
# f(n) = 74 (Function Score)
# g(n) = 34 (Current Step Cost)
# p(n) = 16 (Manhattan Distance)
# s(n) = 16 (Sequence Score)
# h(n) = 60 (Nilsson Sequence)
# search cost: 68
# ------------------------------
# ['2', '1', '6']
# ['*', '8', '3']
# ['4', '7', '5']
# Length of Open: 29
# Length of OPEN_scores: 29
# Length of step_costs: 64
# Open Scores: [76, 77, 80, 75, 77, 77, 74, 74, 81, 84, 85, 82, 79, 83, 86, 85, 84, 84, 81, 87, 80, 80, 81, 80, 91, 91, 93, 93, 94]
# f(n) = 74 (Function Score)
# g(n) = 35 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 70
# ------------------------------
# ['*', '8', '1']
# ['2', '4', '6']
# ['7', '5', '3']
# Length of Open: 29
# Length of OPEN_scores: 29
# Length of step_costs: 65
# Open Scores: [76, 77, 80, 75, 77, 77, 74, 81, 84, 85, 82, 79, 83, 86, 85, 84, 84, 81, 87, 80, 80, 81, 80, 91, 91, 93, 93, 94, 93]
# f(n) = 74 (Function Score)
# g(n) = 36 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# s(n) = 13 (Sequence Score)
# h(n) = 53 (Nilsson Sequence)
# search cost: 72
# ------------------------------
# ['2', '8', '1']
# ['7', '4', '6']
# ['*', '5', '3']
# Length of Open: 29
# Length of OPEN_scores: 29
# Length of step_costs: 66
# Open Scores: [76, 77, 80, 75, 77, 77, 81, 84, 85, 82, 79, 83, 86, 85, 84, 84, 81, 87, 80, 80, 81, 80, 91, 91, 93, 93, 94, 93, 90]
# f(n) = 75 (Function Score)
# g(n) = 37 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# s(n) = 13 (Sequence Score)
# h(n) = 53 (Nilsson Sequence)
# search cost: 74
# ------------------------------
# ['2', '1', '6']
# ['*', '4', '3']
# ['7', '8', '5']
# Length of Open: 30
# Length of OPEN_scores: 30
# Length of step_costs: 68
# Open Scores: [76, 77, 80, 77, 77, 81, 84, 85, 82, 79, 83, 86, 85, 84, 84, 81, 87, 80, 80, 81, 80, 91, 91, 93, 93, 94, 93, 90, 95, 95]
# f(n) = 76 (Function Score)
# g(n) = 38 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 55 (Nilsson Sequence)
# search cost: 76
# ------------------------------
# ['2', '1', '6']
# ['*', '5', '8']
# ['4', '7', '3']
# Length of Open: 31
# Length of OPEN_scores: 31
# Length of step_costs: 70
# Open Scores: [77, 80, 77, 77, 81, 84, 85, 82, 79, 83, 86, 85, 84, 84, 81, 87, 80, 80, 81, 80, 91, 91, 93, 93, 94, 93, 90, 95, 95, 97, 102]
# f(n) = 77 (Function Score)
# g(n) = 39 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 61 (Nilsson Sequence)
# search cost: 78
# ------------------------------
# ['2', '1', '6']
# ['4', '5', '*']
# ['7', '3', '8']
# Length of Open: 32
# Length of OPEN_scores: 32
# Length of step_costs: 72
# Open Scores: [80, 77, 77, 81, 84, 85, 82, 79, 83, 86, 85, 84, 84, 81, 87, 80, 80, 81, 80, 91, 91, 93, 93, 94, 93, 90, 95, 95, 97, 102, 102, 101]
# f(n) = 77 (Function Score)
# g(n) = 40 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 61 (Nilsson Sequence)
# search cost: 80
# ------------------------------
# ['2', '1', '6']
# ['4', '3', '*']
# ['7', '8', '5']
# Length of Open: 33
# Length of OPEN_scores: 33
# Length of step_costs: 74
# Open Scores: [80, 77, 81, 84, 85, 82, 79, 83, 86, 85, 84, 84, 81, 87, 80, 80, 81, 80, 91, 91, 93, 93, 94, 93, 90, 95, 95, 97, 102, 102, 101, 98, 100]
# f(n) = 77 (Function Score)
# g(n) = 41 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 82
# ------------------------------
# ['2', '*', '6']
# ['4', '1', '3']
# ['7', '8', '5']
# Length of Open: 34
# Length of OPEN_scores: 34
# Length of step_costs: 76
# Open Scores: [80, 81, 84, 85, 82, 79, 83, 86, 85, 84, 84, 81, 87, 80, 80, 81, 80, 91, 91, 93, 93, 94, 93, 90, 95, 95, 97, 102, 102, 101, 98, 100, 99, 99]
# f(n) = 79 (Function Score)
# g(n) = 42 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 57 (Nilsson Sequence)
# search cost: 84
# ------------------------------
# ['2', '1', '6']
# ['7', '8', '3']
# ['5', '4', '*']
# Length of Open: 34
# Length of OPEN_scores: 34
# Length of step_costs: 77
# Open Scores: [80, 81, 84, 85, 82, 83, 86, 85, 84, 84, 81, 87, 80, 80, 81, 80, 91, 91, 93, 93, 94, 93, 90, 95, 95, 97, 102, 102, 101, 98, 100, 99, 99, 94]
# f(n) = 80 (Function Score)
# g(n) = 43 (Current Step Cost)
# p(n) = 13 (Manhattan Distance)
# s(n) = 13 (Sequence Score)
# h(n) = 53 (Nilsson Sequence)
# search cost: 86
# ------------------------------
# ['2', '1', '6']
# ['7', '4', '8']
# ['5', '3', '*']
# Length of Open: 34
# Length of OPEN_scores: 34
# Length of step_costs: 78
# Open Scores: [81, 84, 85, 82, 83, 86, 85, 84, 84, 81, 87, 80, 80, 81, 80, 91, 91, 93, 93, 94, 93, 90, 95, 95, 97, 102, 102, 101, 98, 100, 99, 99, 94, 105]
# f(n) = 80 (Function Score)
# g(n) = 44 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 61 (Nilsson Sequence)
# search cost: 88
# ------------------------------
# ['*', '2', '6']
# ['7', '1', '8']
# ['5', '4', '3']
# Length of Open: 34
# Length of OPEN_scores: 34
# Length of step_costs: 79
# Open Scores: [81, 84, 85, 82, 83, 86, 85, 84, 84, 81, 87, 80, 81, 80, 91, 91, 93, 93, 94, 93, 90, 95, 95, 97, 102, 102, 101, 98, 100, 99, 99, 94, 105, 94]
# f(n) = 80 (Function Score)
# g(n) = 45 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# s(n) = 11 (Sequence Score)
# h(n) = 49 (Nilsson Sequence)
# search cost: 90
# ------------------------------
# ['2', '6', '*']
# ['7', '1', '8']
# ['5', '4', '3']
# Length of Open: 34
# Length of OPEN_scores: 34
# Length of step_costs: 80
# Open Scores: [81, 84, 85, 82, 83, 86, 85, 84, 84, 81, 87, 81, 80, 91, 91, 93, 93, 94, 93, 90, 95, 95, 97, 102, 102, 101, 98, 100, 99, 99, 94, 105, 94, 95]
# f(n) = 80 (Function Score)
# g(n) = 46 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# s(n) = 11 (Sequence Score)
# h(n) = 49 (Nilsson Sequence)
# search cost: 92
# ------------------------------
# ['2', '*', '1']
# ['7', '8', '6']
# ['5', '4', '3']
# Length of Open: 35
# Length of OPEN_scores: 35
# Length of step_costs: 82
# Open Scores: [81, 84, 85, 82, 83, 86, 85, 84, 84, 81, 87, 81, 91, 91, 93, 93, 94, 93, 90, 95, 95, 97, 102, 102, 101, 98, 100, 99, 99, 94, 105, 94, 95, 94, 91]
# f(n) = 81 (Function Score)
# g(n) = 47 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# s(n) = 11 (Sequence Score)
# h(n) = 47 (Nilsson Sequence)
# search cost: 94
# ------------------------------
# ['2', '8', '*']
# ['4', '6', '1']
# ['7', '5', '3']
# Length of Open: 35
# Length of OPEN_scores: 35
# Length of step_costs: 83
# Open Scores: [84, 85, 82, 83, 86, 85, 84, 84, 81, 87, 81, 91, 91, 93, 93, 94, 93, 90, 95, 95, 97, 102, 102, 101, 98, 100, 99, 99, 94, 105, 94, 95, 94, 91, 101]
# f(n) = 81 (Function Score)
# g(n) = 48 (Current Step Cost)
# p(n) = 15 (Manhattan Distance)
# s(n) = 15 (Sequence Score)
# h(n) = 59 (Nilsson Sequence)
# search cost: 96
# ------------------------------
# ['*', '1', '6']
# ['2', '7', '8']
# ['5', '4', '3']
# Length of Open: 35
# Length of OPEN_scores: 35
# Length of step_costs: 84
# Open Scores: [84, 85, 82, 83, 86, 85, 84, 84, 87, 81, 91, 91, 93, 93, 94, 93, 90, 95, 95, 97, 102, 102, 101, 98, 100, 99, 99, 94, 105, 94, 95, 94, 91, 101, 98]
# f(n) = 81 (Function Score)
# g(n) = 49 (Current Step Cost)
# p(n) = 11 (Manhattan Distance)
# s(n) = 11 (Sequence Score)
# h(n) = 51 (Nilsson Sequence)
# search cost: 98
# ------------------------------

# %%
main_function(start_state, end_state, 'wrong tiles')
